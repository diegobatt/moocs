# %% [markdown]
# # DAT257x: Reinforcement Learning Explained
#
# ## Lab 6: Function Approximation
#
# ### Exercise 6.1: Q-Learning Agent with Linear Function Approximation

# %%
import numpy as np
import sys

if "../" not in sys.path:
    sys.path.append("../") 

from lib.envs.simple_rooms import SimpleRoomsEnv
from lib.simulation import Experiment

# %%
class Agent(object):  
        
    def __init__(self, actions):
        self.actions = actions
        self.num_actions = len(actions)

    def act(self, state):
        raise NotImplementedError

# %%
class QLearningFAAgent(Agent):
    def __init__(self, actions, obs_size, epsilon=0.01, alpha=0.5, gamma=1):
        super(QLearningFAAgent, self).__init__(actions)
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.theta = np.zeros(obs_size * self.num_actions)
        
        ## TODO 1
        ## Initialize thetas here
        ## In addition, initialize the value of epsilon, alpha and gamma
        
    def featureExtractor(self, state, action):
        feature = None
        
        actionindex = np.zeros(self.num_actions, dtype=np.int)
        actionindex[action] = 1
        feature = np.concatenate([actionindex[i] * state for i in self.actions])
        return feature    
            
    def act(self, state):
        explore = np.random.binomial(1, self.epsilon)
        if explore:
            action = np.random.randint(0, self.num_actions)
        else:
            qs = np.array([np.sum(self.theta.transpose() * self.featureExtractor(state, a)) for a in self.actions])
            argmax = np.where(qs == qs.max())[0]
            if len(argmax) > 1:
                action = np.random.choice(argmax)
            else:
                action = argmax[0]           

        return action           
            
    def learn(self, state1, action1, reward, state2, done):
        
        """
        Q-learning with FA 
        theta <- theta + alpha * td_delta * f(s,a)
        where 
        td_delta = reward + gamma * max(Q(s') - Q(s,a))
        Q(s,a) = thetas * f(s,a)
        max(Q(s')) = max( [ thetas * f(s'a) for a in all actions] )
        
        """
        ## TODO 3
        ## Implement the q-learning update here
        
        maxqnew = np.max([np.sum(self.theta.transpose() * self.featureExtractor(state2, a)) for a in self.actions])
        oldv = np.sum(self.theta.transpose() * self.featureExtractor(state1, action1))
        
        td_target = reward + self.gamma * maxqnew
        td_delta = td_target - oldv
        self.theta += self.alpha * td_delta * self.featureExtractor(state1, action1)

# %%
interactive = True
# %matplotlib nbagg
env = SimpleRoomsEnv()
agent = QLearningFAAgent(range(env.action_space.n),16)
experiment = Experiment(env, agent)
experiment.run_qlearning(10, interactive)
# Out:
# <div id='8c2c1454-64d8-42b7-9134-8343fe39ffa4'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4b7f406b3605> in <module>
#       4 agent = QLearningFAAgent(range(env.action_space.n),16)
#       5 experiment = Experiment(env, agent)
# ----> 6 experiment.run_qlearning(10, interactive)
#
# ~/git-repos/moocs/reinforcement-learning-explained/storage/LabFiles/lib/simulation.py in run_qlearning(self, max_number_of_episodes, interactive, display_frequency)
#     193                 # if interactive display, show update for each step
#     194                 if interactive:
# --> 195                     self.update_display_step()
#     196
#     197             self.episode_length = np.append(self.episode_length,t) # keep episode length - for display
#
# ~/git-repos/moocs/reinforcement-learning-explained/storage/LabFiles/lib/simulation.py in update_display_step(self)
#      58             self.imgplot.set_data(self.env.render(mode='rgb_array'))
#      59
# ---> 60         self.fig.canvas.draw()
#      61
#      62     def update_display_episode(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     148         self._png_is_old = True
#     149         try:
# --> 150             super().draw()
#     151         finally:
#     152             self.manager.refresh_all()  # Swap the frames.
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1188
#    1189         for tick in ticks_to_draw:
# -> 1190             tick.draw(renderer)
#    1191
#    1192         # scale up the axis label box to also find the neighbors, not
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer)
#     297             self.gridline.draw(renderer)
#     298         if self.tick1On:
# --> 299             self.tick1line.draw(renderer)
#     300         if self.tick2On:
#     301             self.tick2line.draw(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in draw(self, renderer)
#     726
#     727         if self._invalidy or self._invalidx:
# --> 728             self.recache()
#     729         self.ind_offset = 0  # Needed for contains() method.
#     730         if self._subslice and self.axes:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in recache(self, always)
#     647             y = self._y
#     648
# --> 649         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     650         self._x, self._y = self._xy.T  # views
#     651
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in column_stack(tup)
#     595
#     596
# --> 597 @array_function_dispatch(_column_stack_dispatcher)
#     598 def column_stack(tup):
#     599     """
#
# KeyboardInterrupt:
# <div id='8f7e6648-4f99-4013-b852-eb5ec20f8648'></div>

# %%
interactive = False
# %matplotlib inline
env = SimpleRoomsEnv()
agent = QLearningFAAgent(range(env.action_space.n),16)
experiment = Experiment(env, agent)
experiment.run_qlearning(50, interactive)
